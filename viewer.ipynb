# %%
import pickle

# %%
with open("temp.pickle", "rb") as tempFile:
    report = pickle.load(tempFile)

# %%
report
# Out:
# {'classification_report': {'0': {'precision': '0.7441860465116279;0.75;0.7948717948717948;0.75;0.7837837837837838;0.7222222222222222;0.7027027027027027;0.896551724137931',
#    'recall': '0.8888888888888888;0.8333333333333334;0.8611111111111112;0.8333333333333334;0.8055555555555556;0.7428571428571429;0.7428571428571429;0.7428571428571429',
#    'f1-score': '0.8101265822784809;0.7894736842105262;0.8266666666666667;0.7894736842105262;0.7945205479452055;0.732394366197183;0.7222222222222223;0.8125',
#    'support': '36;36;36;36;36;35;35;35'},
#   '1': {'precision': '0.8620689655172413;0.8125;0.84375;0.8064516129032258;0.7941176470588235;0.7428571428571429;0.7352941176470589;0.7857142857142857',
#    'recall': '0.6944444444444444;0.7222222222222222;0.7714285714285715;0.7142857142857143;0.7714285714285715;0.7222222222222222;0.6944444444444444;0.9166666666666666',
# ...
