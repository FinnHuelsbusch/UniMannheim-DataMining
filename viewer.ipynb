# %%
import pickle

# %%
with open("temp.pickle", "rb") as tempFile:
    report = pickle.load(tempFile)

# %%
report
# Out:
# {'classification_report': {'0': {'precision': '0.7441860465116279;0.7692307692307693;0.8157894736842105;0.6808510638297872;0.8108108108108109;0.75;0.7380952380952381;0.8125;0.896551724137931',
#    'recall': '0.8888888888888888;0.8333333333333334;0.8611111111111112;0.8888888888888888;0.8333333333333334;0.7714285714285715;0.8857142857142857;0.7428571428571429;0.7428571428571429',
#    'f1-score': '0.8101265822784809;0.8;0.8378378378378377;0.7710843373493975;0.8219178082191781;0.7605633802816902;0.8051948051948051;0.7761194029850748;0.8125',
#    'support': '36;36;36;36;36;35;35;35;35'},
#   '1': {'precision': '0.8620689655172413;0.8181818181818182;0.8484848484848485;0.8333333333333334;0.8235294117647058;0.7714285714285715;0.8620689655172413;0.7692307692307693;0.7857142857142857',
#    'recall': '0.6944444444444444;0.75;0.8;0.5714285714285714;0.8;0.75;0.6944444444444444;0.8333333333333334;0.9166666666666666',
# ...
